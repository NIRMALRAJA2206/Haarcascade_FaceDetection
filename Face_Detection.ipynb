# %% [markdown]
# <a href="https://colab.research.google.com/github/NIRMALRAJA2206/Haarcascade_FaceDetection/blob/main/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Face Detection  - Viola-Jones Method**

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1YSiue_HkgabePWSJSk_dfXkc_htbFx68)

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1UzzB3lBsy9ewAv1u03iuAwnnqjdTZE5L)

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1xcz5AM58oplvDsMa4Mx6Oc97THLY5_bx)

# %% [markdown]
# ***Use Adaboost to get the right Features (Filters that has less error rate)***

# %% [markdown]
# **Finally Apply Cascade to skip the non face region and focus filters on face region**

# %%
# !pip uninstall -y opencv-python
# Out:
# Found existing installation: opencv-python 4.1.2.30
# Uninstalling opencv-python-4.1.2.30:
#   Successfully uninstalled opencv-python-4.1.2.30

# %%
# !pip install opencv-python==3.4.3.18
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python==3.4.3.18
#   Downloading opencv_python-3.4.3.18-cp37-cp37m-manylinux1_x86_64.whl (25.0 MB)
#      |████████████████████████████████| 25.0 MB 1.6 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python==3.4.3.18) (1.21.6)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed opencv-python-3.4.3.18

# %%
# import the necessary packages
from imutils import paths
import cv2
from google.colab.patches import cv2_imshow

# %%
# load the face detector
detector = cv2.CascadeClassifier("/content/sample_data/haarcascade_frontalface_default.xml")

image_paths = "/content/sample_data/images"

# %%
# Loop on images for detecting face
for path in sorted(list(paths.list_images(image_paths))):

	frame = cv2.imread(path)

	gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
	
	faceRects = detector.detectMultiScale(gray, scaleFactor=1.05, minNeighbors=5, minSize=(30, 30), flags=cv2.CASCADE_SCALE_IMAGE)

	# loop over the faces and draw a rectangle around each
	for (x, y, w, h) in faceRects:
		cv2.rectangle(frame, (x, y), (x + w, y + h), (255,0, 0), 3)
	
	no_of_face = len(faceRects)

	cv2.putText(frame, "Face Detected -  "+str(no_of_face), (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)	
	cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=852x631 at 0x7F83CA127190>
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F83BB60E1D0>
# <PIL.Image.Image image mode=RGB size=535x314 at 0x7F83BB903050>
